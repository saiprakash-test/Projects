# %%
# Loading libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
#Loading the data
df = pd.read_csv('Data file.csv')

# %%
df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
#Checking for shape (ie.,number of rows and columns.)
print(df.shape)
# Out:
# (209593, 37)

# %% [markdown]
# Observations :
#
# There are 209593 rows and 37 columns present in the dataset.

# %%
#Checking the columns of dataset
df.columns
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %% [markdown]
# # DATASET DESCRIPTION

# %% [markdown]
# label ==> Flag indicating whether the user paid back the credit amount within 5 days of issuing the loan{1:success, 0:failure}
#
# msisdn ==> mobile number of user
#
# aon	==> age on cellular network in days
#
# daily_decr30 ==> Daily amount spent from main account, averaged over last 30 days (in Indonesian Rupiah)
#
# daily_decr90 ==> Daily amount spent from main account, averaged over last 90 days (in Indonesian Rupiah)
#
# rental30 ==> Average main account balance over last 30 days	(Unsure of given definition)
#
# rental90 ==> Average main account balance over last 90 days	(Unsure of given definition)
#
# last_rech_date_ma ==> Number of days till last recharge of main account
#
# last_rech_date_da ==> Number of days till last recharge of data account
#
# last_rech_amt_ma ==> Amount of last recharge of main account (in Indonesian Rupiah)
#
# cnt_ma_rech30 ==> Number of times main account got recharged in last 30 days
#
# fr_ma_rech30 ==> Frequency of main account recharged in last 30 days (Unsure of given definition)
#
# sumamnt_ma_rech30 ==> Total amount of recharge in main account over last 30 days (in Indonesian Rupiah)
#
# medianamnt_ma_rech30 ==> Median of amount of recharges done in main account over last 30 days at user level (in Indonesian
# Rupiah)
#
# medianmarechprebal30 ==> Median of main account balance just before recharge in last 30 days at user level (in Indonesian
# Rupiah)
#
# cnt_ma_rech90 ==> Number of times main account got recharged in last 90 days
#
# fr_ma_rech90 ==> Frequency of main account recharged in last 90 days (Unsure of given definition)
#
# sumamnt_ma_rech90 ==> Total amount of recharge in main account over last 90 days (in Indonasian Rupiah)
#
# medianamnt_ma_rech90 ==> Median of amount of recharges done in main account over last 90 days at user level (in Indonasian
# Rupiah)
#
# medianmarechprebal90 ==> Median of main account balance just before recharge in last 90 days at user level (in Indonasian
# Rupiah)
#
# cnt_da_rech30 ==> Number of times data account got recharged in last 30 days
#
# fr_da_rech30 ==> Frequency of data account recharged in last 30 days
#
# cnt_da_rech90 ==> Number of times data account got recharged in last 90 days
#
# fr_da_rech90 ==> Frequency of data account recharged in last 90 days
#
# cnt_loans30 ==> Number of loans taken by user in last 30 days
#
# amnt_loans30 ==> Total amount of loans taken by user in last 30 days
#
# maxamnt_loans30 ==> maximum amount of loan taken by the user in last 30 days
#
# (There are only two options: 5 & 10 Rs., for which the user needs to pay back 6 & 12 Rs. respectively)
#
# medianamnt_loans30 ==> Median of amounts of loan taken by the user in last 30 days
#
# cnt_loans90 ==> Number of loans taken by user in last 90 days
#
# amnt_loans90 ==> Total amount of loans taken by user in last 90 days
#
# maxamnt_loans90	==> maximum amount of loan taken by the user in last 90 days
#
# medianamnt_loans90 ==> Median of amounts of loan taken by the user in last 90 days
#
# payback30 ==> Average payback time in days over last 30 days
#
# payback90 ==> Average payback time in days over last 90 days
#
# pcircle ==> telecom circle
#
# pdate ==> date

# %%
#The Column "Unnamed:0" is just a representation of the indexes, so it's useless to keep it,So,removing it.
#pcircle column have a unique value.So,we remove it.
df=df.drop(columns=['Unnamed: 0','pcircle'])
df.head()
# Out:
#    label       msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408I70789  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462I70374  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943I70372  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773I70781  241.0     21.228000     21.228000    159.42    159.42
# 4      1  03813I82730  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  amnt_loans30  \
# 0                2.0                0.0              1539  ...            12
# 1               20.0                0.0              5787  ...            12
# 2                3.0                0.0              1539  ...             6
# 3               41.0                0.0               947  ...            12
# 4                4.0                0.0              2309  ...            42
#
# ...

# %% [markdown]
# Now,the column "Unnamed: 0" was dropped and there is no data loss.

# %%
#Let's check the shape again
df.shape
# Out:
# (209593, 35)

# %%
# checking the datatypes of the dataset.
print(df.dtypes)
# Out:
# label                     int64
# msisdn                   object
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# cnt_loans90             float64
# ...

# %% [markdown]
# Observations :
#
#     Most of the columns in the dataset are of numerical type.Only columns "msisdn","pcircle" and "pdate" are categorical.

# %%
#Checking the information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 35 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   msisdn                209593 non-null  object
#  2   aon                   209593 non-null  float64
#  3   daily_decr30          209593 non-null  float64
#  4   daily_decr90          209593 non-null  float64
#  5   rental30              209593 non-null  float64
#  6   rental90              209593 non-null  float64
#  7   last_rech_date_ma     209593 non-null  float64
#  8   last_rech_date_da     209593 non-null  float64
#  9   last_rech_amt_ma      209593 non-null  int64
#  10  cnt_ma_rech30         209593 non-null  int64
#  11  fr_ma_rech30          209593 non-null  float64
#  12  sumamnt_ma_rech30     209593 non-null  float64
#  13  medianamnt_ma_rech30  209593 non-null  float64
# ...

# %% [markdown]
# Observations :
#
# From the information of the dataset,we see that all the columns have no missing(null) values and right to it shows the datatypes of all the columns.

# %%
#Checking the null values if any
df.isnull().sum()
# Out:
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pdate                   0
# dtype: int64

# %% [markdown]
# There are no null values in the dataset.

# %% [markdown]
# # Summary Statistics

# %%
df.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755168  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000      209593.000000      209593.000000
# mean     2692.581910    3483.406534        3755.847800        3712.202921
# std      4308.586781    5770.461279       53905.892230       53374.833430
# min    -23737.140000  -24720.580000         -29.000000         -29.000000
# ...

# %% [markdown]
# # To check the Correlation

# %%
df.corr()
# Out:
#                          label       aon  daily_decr30  daily_decr90  \
# label                 1.000000 -0.003785      0.168298      0.166150
# aon                  -0.003785  1.000000      0.001104      0.000374
# daily_decr30          0.168298  0.001104      1.000000      0.977704
# daily_decr90          0.166150  0.000374      0.977704      1.000000
# rental30              0.058085 -0.000960      0.442066      0.434685
# rental90              0.075521 -0.000790      0.458977      0.471730
# last_rech_date_ma     0.003728  0.001692      0.000487      0.000908
# last_rech_date_da     0.001711 -0.001693     -0.001636     -0.001886
# last_rech_amt_ma      0.131804  0.004256      0.275837      0.264131
# cnt_ma_rech30         0.237331 -0.003148      0.451385      0.426707
# fr_ma_rech30          0.001330 -0.001163     -0.000577     -0.000343
# sumamnt_ma_rech30     0.202828  0.000707      0.636536      0.603886
# medianamnt_ma_rech30  0.141490  0.004306      0.295356      0.282960
# ...

# %%
#visualizing correlation using heatmap
plt.figure(figsize=(28,28))
sns.heatmap(df.corr(),annot = True,cmap='coolwarm');

# %% [markdown]
# Observations :
#
# From the above heatmap,we observe that "daily_decr30" is highly positively correlated with "daily_decr90" and "rental30" is also highly correlated with "rental90".
#
# The column "cnt_ma_rech30" is negatively correlated with "fr_ma_rech90" and "fr_ma_rech90" is negatively correlated with "cnt_ma_rech90"

# %%
plt.figure(figsize=(8,6))
df.drop('label',axis = 1).corrwith(df['label']).plot(kind='bar',grid=True)
plt.xticks(rotation = 90)
plt.title('Correlation with target variable');

# %% [markdown]
# The columns “cnt_ma_rech30” & “cnt_ma_rech90” which means Number of times main account got recharged in last 30 days & 90 days respectively are highly correlated with the target variable(“label”).
#
# The columns “fr_ma_rech90” (Frequency of main account recharged in last 30 days), “aon” (age on cellular network in days) and “medianmarechprebal30” (Median of main account balance just before recharge in last 30 days at user level (in Indonesian Rupiah)) are negatively correlated with the target variable.

# %% [markdown]
# # Exploratory Data Analysis

# %%
df['label'].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# Observations :
#
# ==> The column 'label' is the target variable which is to be predicted whether the customer is defaulter or non-defaulter.
#
# ==> label has two unique values i.e., 0 &1.

# %%
df['label'].value_counts()
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %% [markdown]
# Observations :
#
# ==>   Label ‘1’ indicates that the loan has been payed i.e. Non- defaulter, while, Label ‘0’ indicates that the loan has not been payed i.e. defaulter.
#
# ==> Label 1 has lot more values than label 0.So,Class imbalance problem arises. This can be done by Undersampling/Oversampling which is done before model training.

# %% [markdown]
# # Univariate Analysis

# %%
# checking the label count
plt.figure(figsize=[5,5])
sns.countplot(x = 'label', data = df,palette='rocket')
plt.title('Count of label values',fontsize = 25)
plt.xlabel('label')
plt.ylabel('count')
plt.show()

print('\n')
print('label :')
print(df['label'].value_counts())
# Out:
# label :
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %% [markdown]
# Observations :
#
#     Most of the users paid back the credit amount within 5 days of issuing the loan approximately 87%.

# %%
# checking the Amount of last recharge count
plt.figure(figsize=[15,5])
sns.countplot(x = 'last_rech_amt_ma', data = df,palette='rainbow')
plt.title('Count of last recharge',fontsize = 25)
plt.xlabel('last_rech_amt_ma')
plt.ylabel('count')
plt.xticks(rotation = 90)
plt.show()

print('\n')
print('Amount of last recharge of main account (in Indonesian Rupiah) :')
print(df['last_rech_amt_ma'].value_counts())
# Out:
# Amount of last recharge of main account (in Indonesian Rupiah) :
# 1539     56297
# 770      41766
# 0        20995
# 773      19523
# 2309     16113
#          ...
# 19913        1
# 10454        1
# 14783        1
# 4066         1
# 22609        1
# Name: last_rech_amt_ma, Length: 70, dtype: int64

# %% [markdown]
# Observations :
#
# Most of the users i.e., 56297 recharged their main account with an amount of 1539.

# %%
# checking the Count of main account got recharged in last 30 days
plt.figure(figsize=[15,5])
sns.countplot(x = 'cnt_ma_rech30', data = df,palette='deep')
plt.title('Count of main account got recharged in last 30 days',fontsize = 25)
plt.xlabel('cnt_ma_rech30')
plt.ylabel('count')
plt.xticks(rotation = 90)
plt.show()

print('\n')
print('Number of times main account got recharged in last 30 days :')
print(df['cnt_ma_rech30'].value_counts())
# Out:
# Number of times main account got recharged in last 30 days :
# 1      37238
# 2      31216
# 0      27979
# 3      25519
# 4      20258
#        ...
# 64         1
# 63         1
# 59         1
# 50         1
# 115        1
# Name: cnt_ma_rech30, Length: 71, dtype: int64

# %% [markdown]
# Observations :
#
# Most of the users have recharged their main account once in last 30 days.

# %%
# checking the Count of main account got recharged in last 90 days
plt.figure(figsize=[18,8])
sns.countplot(x = 'cnt_ma_rech90', data = df,palette='deep')
plt.title('Count of main account got recharged in last 90 days',fontsize = 25)
plt.xlabel('cnt_ma_rech90')
plt.ylabel('count')
plt.xticks(rotation = 90)
plt.show()

print('\n')
print('Number of times main account got recharged in last 90 days :')
print(df['cnt_ma_rech90'].value_counts())
# Out:
# Number of times main account got recharged in last 90 days :
# 1      27898
# 2      24052
# 0      20950
# 3      20446
# 4      17329
#        ...
# 151        1
# 336        1
# 121        1
# 172        1
# 127        1
# Name: cnt_ma_rech90, Length: 110, dtype: int64

# %% [markdown]
# Observations :
#
# Most of the users recharged their account once in last 90 days.It is similar as in the case of 30 days.

# %%
# checking the Count of main account got recharged in last 90 days
plt.figure(figsize=[20,5])
sns.countplot(x = 'fr_ma_rech90', data = df,palette='deep')
plt.title('Frequency of main account recharged in last 90 days',fontsize = 25)
plt.xlabel('fr_ma_rech90')
plt.ylabel('count')
plt.xticks(rotation = 90)
plt.show()

print('\n')
print('Frequency of main account recharged in last 90 days :')
print(df['fr_ma_rech90'].value_counts())
# Out:
# Frequency of main account recharged in last 90 days :
# 0     65753
# 1     24373
# 2     19285
# 3     13192
# 4     10021
#       ...
# 80        7
# 81        7
# 88        5
# 84        4
# 87        1
# Name: fr_ma_rech90, Length: 89, dtype: int64

# %% [markdown]
# Observations :
#
# The above countplot shows that many users doesn't recharge frequently.

# %%
# checking the Count of data account got recharged in last 90 days
plt.figure(figsize=[15,5])
sns.countplot(x = 'cnt_da_rech90', data = df,palette='rocket')
plt.title('Number of times data account got recharged in last 90 days',fontsize = 25)
plt.xlabel('cnt_da_rech90')
plt.ylabel('count')
plt.xticks(rotation = 90)
plt.show()

print('\n')
print('Number of times data account got recharged in last 90 days :')
print(df['cnt_da_rech90'].value_counts())
# Out:
# Number of times data account got recharged in last 90 days :
# 0     204226
# 1       4173
# 2        556
# 3        227
# 4        150
# 5         74
# 6         49
# 7         36
# 8         30
# 9         18
# 14        10
# 12         7
# 11         7
# 10         6
# 13         6
# 16         4
# 18         3
# 15         2
# 30         1
# 17         1
# 19         1
# 20         1
# 22         1
# 25         1
# 27         1
# 28         1
# 38         1
# Name: cnt_da_rech90, dtype: int64

# %% [markdown]
# Observations :
#
#     Above 2 lakh users has not recharged their data account for the last 90 days and are the highest users.

# %%
# checking the Number of loans taken by user in last 30 days
plt.figure(figsize=[15,5])
sns.countplot(x = 'cnt_loans30', data = df,palette='deep')
plt.title('Number of loans taken by user in last 30 days',fontsize = 25)
plt.xlabel('cnt_loans30')
plt.ylabel('count')
plt.xticks(rotation = 90)
plt.show()

print('\n')
print('Number of loans taken by user in last 30 days :')
print(df['cnt_loans30'].value_counts())
# Out:
# Number of loans taken by user in last 30 days :
# 1     83432
# 2     42665
# 3     27050
# 4     17499
# 5     11673
# 6      7773
# 7      5041
# 8      3384
# 0      3259
# 9      2273
# 10     1571
# 11     1143
# 12      793
# 13      547
# 14      383
# 15      270
# 16      213
# 17      164
# 18       98
# 19       77
# 20       54
# 21       45
# 22       42
# 23       38
# 25       19
# 26       17
# 27       15
# 24       13
# 29        9
# 31        8
# 28        7
# 30        4
# 32        4
# 33        3
# 38        2
# 41        1
# 44        1
# 36        1
# 35        1
# 50        1
# Name: cnt_loans30, dtype: int64

# %% [markdown]
# Observations :
#
# Most of the people had took loan once in a month are highest.

# %%
sns.countplot(x = 'maxamnt_loans90', data = df)

# %% [markdown]
# Observations :
#
# ==> Most of the customers took 6 times maximum amount of loan in the past 90 days.

# %%
sns.countplot(x = 'medianamnt_loans90', data = df)

# %%
df1 = df.sort_values(by="pdate",ascending=True)
df1['pdate']
# Out:
# 179785    2016-06-01
# 13379     2016-06-01
# 9902      2016-06-01
# 204478    2016-06-01
# 75766     2016-06-01
#              ...
# 201205    2016-08-21
# 158926    2016-08-21
# 139702    2016-08-21
# 186681    2016-08-21
# 169990    2016-08-21
# Name: pdate, Length: 209593, dtype: object

# %%
# checking the Number of loans taken by user in last 30 days
plt.figure(figsize=[15,5])
sns.countplot(x = 'pdate', data = df1,palette='deep')
plt.title('Number of users taken loan on a particular date',fontsize = 25)
plt.xlabel('pdate')
plt.ylabel('count')
plt.xticks(rotation = 90)
plt.show()

print('\n')
print('Number of users taken loan on a particular date :')
print(df['pdate'].value_counts())
# Out:
# Number of users taken loan on a particular date :
# 2016-07-04    3150
# 2016-07-05    3127
# 2016-07-07    3116
# 2016-06-20    3099
# 2016-06-17    3082
#               ...
# 2016-06-04    1559
# 2016-08-18    1407
# 2016-08-19    1132
# 2016-08-20     788
# 2016-08-21     324
# Name: pdate, Length: 82, dtype: int64

# %% [markdown]
# Observations :
#
#     ==> Most of the customers took loan on 2016-07-04.

# %% [markdown]
# # Bivariate Analysis

# %%
plt.figure(figsize=[5,5])
sns.barplot(df['label'],df['medianamnt_loans90']);
plt.title('label vs medianamnt_loans90',fontsize = 15)
plt.xlabel('label')
plt.ylabel('medianamnt_loans90')
plt.xticks(rotation = 90)
plt.show()

print(df.groupby('label')['medianamnt_loans90'].value_counts())
# Out:
# label  medianamnt_loans90
# 0      0.0                    25230
#        1.0                      485
#        0.5                      447
# 1      0.0                   172194
#        1.0                     5687
#        0.5                     5221
#        2.0                      307
#        1.5                       19
#        3.0                        3
# Name: medianamnt_loans90, dtype: int64

# %% [markdown]
# Observations :
#
# Most of the users Median of amounts of loan taken by the user in last 90 days have paid.

# %%
plt.figure(figsize=[15,5])
plt.xticks(rotation = 90)
sns.barplot(df['cnt_ma_rech30'],df['payback30'],hue=df['label']);

# %% [markdown]
# Observations :
#
#  ==> The users who have recharged main account thrice and didn't payed back the amount in the last 30 days are more in number.

# %%
plt.figure(figsize=[15,5])
plt.xticks(rotation = 90)
sns.barplot(df['cnt_ma_rech90'],df['payback30'],hue=df['label']);

# %% [markdown]
# Observations :
#
# ==> The users who have recharged main account five times for last 90 days and didn't payed back the amount in the last 30 days are more in number.

# %%
plt.figure(figsize=[25,5])
plt.xticks(rotation = 90)
sns.barplot(df['cnt_ma_rech90'],df['payback90'],hue=df['label']);

# %% [markdown]
# Observations :
#
# ==> The users who have recharged main account four times and didn't payed back the amount in the last 90 days are more in number.

# %%
plt.figure(figsize=[25,5])
plt.xticks(rotation = 90)
sns.barplot(df['cnt_da_rech90'],df['payback90'],hue=df['label']);

# %% [markdown]
# Observations:
#
# ==> The users who have recharged the data account 28 times and repaying it are more in number.

# %%
plt.figure(figsize=[25,5])
plt.xticks(rotation = 90)
sns.barplot(df['cnt_da_rech90'],df['payback30'],hue=df['label']);

# %% [markdown]
# Observations:
#
# ==> The users who have recharged the data account 18 times for last 90 days doesnot paid the loan for the last 30 days.

# %%
plt.figure(figsize=[25,15])
plt.xticks(rotation = 90)
sns.barplot(df['fr_ma_rech90'],df['payback30'],hue=df['label']);

# %% [markdown]
# Observations:
#
# ==> The users who have frequency the main account 21 times for last 90 days doesnot paid the loan for the last 30 days and they are more in number..

# %%
plt.figure(figsize=[15,5])
plt.xticks(rotation = 90)
sns.barplot(df['fr_da_rech90'],df['payback30'],hue=df['label']);

# %% [markdown]
# Observations:
#
# ==> The users who have recharged the data account 8 times for last 90 days doesnot paid the loan for the last 30 days.

# %%
sns.pairplot(df[['daily_decr30', 'daily_decr90', 'rental30','rental90','label']])

# %% [markdown]
# Observations :
#
# ==> From the pair plot,Customers who spent Daily average amount spent from main account over last 30 & 90 days ,Average main account balance over last 30 & 90 days have less loan defaulters.

# %%
sns.pairplot(df[['cnt_loans30', 'amnt_loans30', 'maxamnt_loans30','payback30','label']])

# %% [markdown]
# Observations :
#
# ==> Number of loans taken by user and Total amount of loans in last 30 days have linear relation with each other.

# %%
sns.pairplot(df[['cnt_loans90', 'amnt_loans90', 'maxamnt_loans90','payback90','label']])

# %%
sns.relplot(data=df, x="payback30", y="amnt_loans30", hue="label");

# %% [markdown]
# Observations:
#
#    ==> Most of the users have paid the total amount of loans in the last 30 days. There is an inverse relation between them.

# %%
sns.relplot(data=df, x="cnt_loans30", y="amnt_loans30", hue="label");

# %% [markdown]
# Observations :
#
# ==> There is a linear relation between Number and amount of loans taken by user in last 30 days. Most of the users have repaid the loan.

# %%
sns.scatterplot(data=df, y="rental90", x="label")

# %%
sns.scatterplot(data=df, y="sumamnt_ma_rech90", x="label")

# %%
sns.relplot(x="rental30", y="rental90", hue="label", data=df);

# %% [markdown]
# Obervations :
#
#     ==> Most of the customers have average main account balance.So,they paid the loan in the specified time.

# %% [markdown]
# # Converting Categorical columns to Numerical columns

# %%
from sklearn.preprocessing import LabelEncoder
df['msisdn']= LabelEncoder().fit_transform(df['msisdn']) 
df['msisdn'].unique()
# Out:
# array([ 40191, 142291,  33594, ...,  42866, 111388, 121263])

# %% [markdown]
# Observations :
#
#     ==> Now,the "msisdn" values are converted from categorical to numericals.

# %%
df['pdate']
# Out:
# 0         2016-07-20
# 1         2016-08-10
# 2         2016-08-19
# 3         2016-06-06
# 4         2016-06-22
#              ...
# 209588    2016-06-17
# 209589    2016-06-12
# 209590    2016-07-29
# 209591    2016-07-25
# 209592    2016-07-07
# Name: pdate, Length: 209593, dtype: object

# %% [markdown]
# Observations :
#
# ==> The column "pdate" is in ‘yyyy-mm-dd’ format.To convert it into numericals we import datetime library.

# %%
import datetime as dt
df['pdate'] = pd.to_datetime(df['pdate']) 
df['pdate']=df['pdate'].map(dt.datetime.toordinal)
df.head()
# Out:
#    label  msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0   40191  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  142291  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1   33594  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  104157  241.0     21.228000     21.228000    159.42    159.42
# 4      1    6910  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  amnt_loans30  \
# 0                2.0                0.0              1539  ...            12
# 1               20.0                0.0              5787  ...            12
# 2                3.0                0.0              1539  ...             6
# 3               41.0                0.0               947  ...            12
# 4                4.0                0.0              2309  ...            42
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# ...

# %% [markdown]
# Observations :
#
# ==> Now,the column "pdate" is changed to numericals.

# %%
for col in df.columns:
    df.loc[df[col]<=0,col]=0

# %% [markdown]
# Observations :
#
# ==> We observe that most of the columns have negative values.We change the negative values to zero since,in the real world money recharge,loan can't be negative.

# %% [markdown]
# # Checking for Skewness

# %%
df.skew()
# Out:
# label                   -2.270254
# msisdn                   0.000719
# aon                     10.392950
# daily_decr30             3.946238
# daily_decr90             4.252572
# rental30                 4.549979
# rental90                 4.458345
# last_rech_date_ma       14.790974
# last_rech_date_da       14.814857
# last_rech_amt_ma         3.781149
# cnt_ma_rech30            3.283842
# fr_ma_rech30            14.772833
# sumamnt_ma_rech30        6.386787
# medianamnt_ma_rech30     3.512324
# medianmarechprebal30    14.779881
# cnt_ma_rech90            3.425254
# fr_ma_rech90             2.285423
# sumamnt_ma_rech90        4.897950
# medianamnt_ma_rech90     3.752706
# medianmarechprebal90    45.079058
# cnt_da_rech30           17.818364
# fr_da_rech30            14.776430
# cnt_da_rech90           27.267278
# fr_da_rech90            28.988083
# cnt_loans30              2.713421
# amnt_loans30             2.975719
# maxamnt_loans30         17.658052
# ...

# %%
#Let's visualize the skewness with the distplots.
from scipy.stats import skew

for col in df:
    print(col)
    print(skew(df[col]))
    
    plt.figure()
    sns.distplot(df[col])
    plt.show()
# Out:
# label
# -2.2702374722925835
# msisdn
# 0.000718895751350096
# aon
# 10.392875621677325
# daily_decr30
# 3.946209754928963
# daily_decr90
# 4.252541306911089
# rental30
# 4.549946396300167
# rental90
# 4.458313556624738
# last_rech_date_ma
# 14.790868306409127
# last_rech_date_da
# 14.814751207402098
# last_rech_amt_ma
# 3.781121576407043
# cnt_ma_rech30
# 3.2838180013879295
# fr_ma_rech30
# 14.772726911394182
# sumamnt_ma_rech30
# 6.386741340983388
# medianamnt_ma_rech30
# 3.512299013694375
# medianmarechprebal30
# 14.779774755585821
# cnt_ma_rech90
# 3.425229132902297
# fr_ma_rech90
# 2.2854064403417964
# sumamnt_ma_rech90
# 4.897914558768428
# medianamnt_ma_rech90
# 3.752679166445998
# medianmarechprebal90
# 45.07873550490768
# cnt_da_rech30
# 17.818236613825185
# fr_da_rech30
# 14.776324483257788
# cnt_da_rech90
# 27.26708253699577
# fr_da_rech90
# 28.987875246755486
# cnt_loans30
# 2.7134016676460946
# amnt_loans30
# 2.9756981766272026
# maxamnt_loans30
# 17.657925277921116
# ...

# %%
#Treating skewness via log method
columns = df.columns
for col in columns:
    if df[col].skew()>2:
        df[col] = np.log1p(df[col])

# %%
df.skew()
# Out:
# label                   -2.270254
# msisdn                   0.000719
# aon                      0.924923
# daily_decr30            -0.453719
# daily_decr90            -0.429730
# rental30                -1.320837
# rental90                -1.288806
# last_rech_date_ma        4.361266
# last_rech_date_da        9.853534
# last_rech_amt_ma        -2.190580
# cnt_ma_rech30           -0.002013
# fr_ma_rech30             4.071763
# sumamnt_ma_rech30       -1.762898
# medianamnt_ma_rech30    -1.867802
# medianmarechprebal30     0.280374
# cnt_ma_rech90           -0.033410
# fr_ma_rech90             0.518606
# sumamnt_ma_rech90       -2.023724
# medianamnt_ma_rech90    -2.235333
# medianmarechprebal90    -0.550959
# cnt_da_rech30           13.709136
# fr_da_rech30            13.840685
# cnt_da_rech90            8.491552
# fr_da_rech90            18.083017
# cnt_loans30              0.720970
# amnt_loans30            -0.026725
# maxamnt_loans30          9.512099
# ...

# %%
df.describe()
# Out:
#                label         msisdn            aon   daily_decr30  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177   93100.650179       6.194547       6.349328
# std         0.330519   53758.461427       1.250443       2.946872
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.000000   46506.000000       5.509388       3.771381
# 50%         1.000000   93073.000000       6.269096       7.293137
# 75%         1.000000  139626.000000       6.890609       8.888067
# max         1.000000  186242.000000      13.815372      12.490977
#
#         daily_decr90       rental30       rental90  last_rech_date_ma  \
# count  209593.000000  209593.000000  209593.000000      209593.000000
# mean        6.395717       6.531384       6.713845           1.522056
# std         2.985165       2.309226       2.373866           1.267104
# min         0.000000       0.000000       0.000000           0.000000
# ...

# %%
for col in df.columns:
    sns.boxplot(df[col])
    plt.show()

# %% [markdown]
# Observations:
#
# From the above box plots,outliers are seen clearly.

# %%
for col in df.columns:
    IQR = df[col].quantile(0.75)-df[col].quantile(0.25)
    upper_bridge = df[col].quantile(0.75)+(IQR*1.5)
    lower_bridge = df[col].quantile(0.25)-(IQR*1.5)
    df.loc[df[col]>=upper_bridge, col]=upper_bridge

# %%
df.describe()
# Out:
#                label         msisdn            aon   daily_decr30  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177   93100.650179       6.149250       6.349328
# std         0.330519   53758.461427       1.050970       2.946872
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.000000   46506.000000       5.509388       3.771381
# 50%         1.000000   93073.000000       6.269096       7.293137
# 75%         1.000000  139626.000000       6.890609       8.888067
# max         1.000000  186242.000000       8.962440      12.490977
#
#         daily_decr90       rental30       rental90  last_rech_date_ma  \
# count  209593.000000  209593.000000  209593.000000      209593.000000
# mean        6.395717       6.531382       6.713845           1.474808
# std         2.985165       2.309221       2.373866           0.957628
# min         0.000000       0.000000       0.000000           0.000000
# ...

# %% [markdown]
# Observations :
#
# ==> The difference between 75% and max value is decreased when treating outliers.So,we can say that outliers are removed.

# %%
#Seperating into input and output variables
x = df.drop(['label'], axis=1)
y = df['label']

# %%
print(x.shape,'\t',y.shape)
# Out:
# (209593, 34) 	 (209593,)

# %%
#This is a class imbalance problem.So,let's try Undersampling & Oversampling Techniques

# %% [markdown]
# # Oversampling Using SMOTE Technique

# %%
print("Before OverSampling, counts of label '1': {}".format(sum(y == 1)))
print("Before OverSampling, counts of label '0': {} \n".format(sum(y == 0)))
# Out:
# Before OverSampling, counts of label '1': 183431
# Before OverSampling, counts of label '0': 26162

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 2) 
x_res, y_res = sm.fit_sample(x, y.ravel())

# %%
print("After OverSampling, counts of label '1': {}".format(sum(y_res == 1))) 
print("After OverSampling, counts of label '0': {}".format(sum(y_res == 0)))
# Out:
# After OverSampling, counts of label '1': 183431
# After OverSampling, counts of label '0': 183431

# %%
# Now both the classes(0&1) is balanced.

# %%
print(x_res.shape,'\t',y_res.shape)
# Out:
# (366862, 34) 	 (366862,)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_res = sc.fit_transform(x_res)

# %%
#Breaking our input and target variable into train and test data
from sklearn.model_selection import train_test_split
x_res_train,x_res_test,y_res_train,y_res_test=train_test_split(x_res,y_res,test_size=0.2,random_state=42)

# %%
# describing info about train and test set 
print("Number transactions x_train dataset: ", x_res_train.shape) 
print("Number transactions y_train dataset: ", y_res_train.shape) 
print("Number transactions x_test dataset: ", x_res_test.shape) 
print("Number transactions y_test dataset: ", y_res_test.shape)
# Out:
# Number transactions x_train dataset:  (293489, 34)
# Number transactions y_train dataset:  (293489,)
# Number transactions x_test dataset:  (73373, 34)
# Number transactions y_test dataset:  (73373,)

# %%
# importing all the model libraries and metrics
from sklearn.model_selection import GridSearchCV,cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
# Checking the model performance by for loop without hyperparameter tuning
model = [LogisticRegression(),GaussianNB(),DecisionTreeClassifier()]

for m in model:
    m.fit(x_res_train,y_res_train)
    m.score(x_res_train,y_res_train)
    pred=m.predict(x_res_test)
    print('Accuracy score of',m,'is:')
    print(accuracy_score(y_res_test,pred))
    print(confusion_matrix(y_res_test,pred))
    print(classification_report(y_res_test,pred))
    print('==============================================================================================')
    print('\n')
# Out:
# Accuracy score of LogisticRegression() is:
# 0.7793738841263135
# [[28969  7478]
#  [ 8710 28216]]
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.79      0.78     36447
#          1.0       0.79      0.76      0.78     36926
#
#     accuracy                           0.78     73373
#    macro avg       0.78      0.78      0.78     73373
# weighted avg       0.78      0.78      0.78     73373
#
# ...
#
#
# Accuracy score of GaussianNB() is:
# 0.6753574203044717
# [[35230  1217]
#  [22603 14323]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.97      0.75     36447
#          1.0       0.92      0.39      0.55     36926
#
#     accuracy                           0.68     73373
#    macro avg       0.77      0.68      0.65     73373
# weighted avg       0.77      0.68      0.65     73373
#
# ...
#
#
# Accuracy score of DecisionTreeClassifier() is:
# 0.9226554727215733
# [[33735  2712]
#  [ 2963 33963]]
# ...

# %% [markdown]
# DecisionTreeClassifier has the best Accuracy score.Let's also check the boosting models.

# %%
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier

model = [RandomForestClassifier(),GradientBoostingClassifier()]

for m in model:
    m.fit(x_res_train,y_res_train)
    m.score(x_res_train,y_res_train)
    pred=m.predict(x_res_test)
    print('Accuracy score of',m,'is:')
    print(accuracy_score(y_res_test,pred))
    print(confusion_matrix(y_res_test,pred))
    print(classification_report(y_res_test,pred))
    print('==============================================================================================')
    print('\n')
# Out:
# Accuracy score of RandomForestClassifier() is:
# 0.9503768416174887
# [[34029  2418]
#  [ 1223 35703]]
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.93      0.95     36447
#          1.0       0.94      0.97      0.95     36926
#
#     accuracy                           0.95     73373
#    macro avg       0.95      0.95      0.95     73373
# weighted avg       0.95      0.95      0.95     73373
#
# ...
#
#
# Accuracy score of GradientBoostingClassifier() is:
# 0.9306965777602115
# [[34004  2443]
#  [ 2642 34284]]
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.93      0.93     36447
#          1.0       0.93      0.93      0.93     36926
#
#     accuracy                           0.93     73373
#    macro avg       0.93      0.93      0.93     73373
# weighted avg       0.93      0.93      0.93     73373
#
# ...

# %% [markdown]
# Observations:
#
# ==> Random Forest Classifier gives the better accuracy score.Let's also check hyperparameter tuning to know whether the model is overfitting/underfitting.

# %%
#using GridsearchCV to find the best parameter in DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

tree_para = {'criterion':['gini','entropy'],'max_depth':[2,4,6,8,10,12]}
clf = GridSearchCV(DecisionTreeClassifier(), tree_para, cv=5)
clf.fit(x_res, y_res)
print(clf.best_params_)
# Out:
# {'criterion': 'gini', 'max_depth': 12}

# %%
model_params = {
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'n_estimators': [50,100,200]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'C': [1,5,10]
        }
    }
}

# %%
scores = []

for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(x_res, y_res)
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })

# %%
df1 = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df1
# Out:
#                  model  best_score            best_params
# 0        random_forest    0.931097  {'n_estimators': 200}
# 1  logistic_regression    0.780858               {'C': 1}

# %%
#Best fit parameters obtained after hyperparameter tuning using GridSearchCV
lr=LogisticRegression(C = 1)
rf=RandomForestClassifier(n_estimators = 200)
dt=DecisionTreeClassifier(criterion = 'gini',max_depth = 12)

# %%
#cross validating all the models
models=[lr,GaussianNB(),dt,rf,GradientBoostingClassifier()] 
for m in models:
    score = cross_val_score(m,x_res,y_res,cv=4,scoring='accuracy')
    print('Model',m)
    print('Score:',score)
    print('Mean Score:',score.mean())
    print('Standard deviation:',score.std())
    print('==========================================================')
    print('\n')
# Out:
# Model LogisticRegression(C=1)
# Score: [0.77377993 0.78370186 0.78150793 0.78416835]
# Mean Score: 0.7807895178493387
# Standard deviation: 0.004169792879275421
# ...
#
#
# Model GaussianNB()
# Score: [0.67654499 0.67830041 0.67854767 0.67835141]
# Mean Score: 0.6779361204672292
# Standard deviation: 0.0008084591682161169
# ...
#
#
# Model DecisionTreeClassifier(max_depth=12)
# Score: [0.81363121 0.94444808 0.9494194  0.94680259]
# Mean Score: 0.9135753200695409
# Standard deviation: 0.0577295464829417
# ...
#
#
# Model RandomForestClassifier(n_estimators=200)
# Score: [0.79386367 0.97652536 0.97621981 0.97688492]
# Mean Score: 0.9308734383987707
# Standard deviation: 0.07910297920260803
# ...
#
#
# Model GradientBoostingClassifier()
# Score: [0.82839417 0.95233111 0.94818732 0.94998637]
# Mean Score: 0.9197247431573832
# Standard deviation: 0.0527501953592195
# ...

# %%
# Checking the model performance by for loop
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

model = [lr,GaussianNB(),dt]

for m in model:
    m.fit(x_res_train,y_res_train)
    m.score(x_res_train,y_res_train)
    pred=m.predict(x_res_test)
    print('Accuracy score of',m,'is:')
    print(accuracy_score(y_res_test,pred))
    print(confusion_matrix(y_res_test,pred))
    print(classification_report(y_res_test,pred))
    print('==============================================================================================')
    print('\n')
# Out:
# Accuracy score of LogisticRegression(C=1) is:
# 0.7793738841263135
# [[28969  7478]
#  [ 8710 28216]]
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.79      0.78     36447
#          1.0       0.79      0.76      0.78     36926
#
#     accuracy                           0.78     73373
#    macro avg       0.78      0.78      0.78     73373
# weighted avg       0.78      0.78      0.78     73373
#
# ...
#
#
# Accuracy score of GaussianNB() is:
# 0.6753574203044717
# [[35230  1217]
#  [22603 14323]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.97      0.75     36447
#          1.0       0.92      0.39      0.55     36926
#
#     accuracy                           0.68     73373
#    macro avg       0.77      0.68      0.65     73373
# weighted avg       0.77      0.68      0.65     73373
#
# ...
#
#
# Accuracy score of DecisionTreeClassifier(max_depth=12) is:
# 0.9275619096943017
# [[33392  3055]
# ...

# %% [markdown]
# DecisionTreeClassifier has good metrics.Let's also check ensemble techniques to boostup the accuracy.

# %% [markdown]
# # Using Ensemble Techniques to Boostup our Accuracy

# %%
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier

model = [rf,GradientBoostingClassifier()]

for m in model:
    m.fit(x_res_train,y_res_train)
    m.score(x_res_train,y_res_train)
    pred=m.predict(x_res_test)
    print('Accuracy score of',m,'is:')
    print(accuracy_score(y_res_test,pred))
    print(confusion_matrix(y_res_test,pred))
    print(classification_report(y_res_test,pred))
    print('==============================================================================================')
    print('\n')
# Out:
# Accuracy score of RandomForestClassifier(n_estimators=200) is:
# 0.950485873550216
# [[34030  2417]
#  [ 1216 35710]]
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.93      0.95     36447
#          1.0       0.94      0.97      0.95     36926
#
#     accuracy                           0.95     73373
#    macro avg       0.95      0.95      0.95     73373
# weighted avg       0.95      0.95      0.95     73373
#
# ...
#
#
# Accuracy score of GradientBoostingClassifier() is:
# 0.9306965777602115
# [[34004  2443]
#  [ 2642 34284]]
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.93      0.93     36447
#          1.0       0.93      0.93      0.93     36926
#
#     accuracy                           0.93     73373
#    macro avg       0.93      0.93      0.93     73373
# weighted avg       0.93      0.93      0.93     73373
#
# ...

# %% [markdown]
# RandomForestClassifier has good metrics compare with other models. So,we choose RandomForestClassifier as the best model.

# %% [markdown]
# # Using NearMiss Algorithm for undersampling

# %%
print("Before Undersampling, counts of label '1': {}".format(sum(y == 1))) 
print("Before Undersampling, counts of label '0': {} \n".format(sum(y == 0))) 

# applying near miss 
from imblearn.under_sampling import NearMiss 
nr = NearMiss() 

x_miss, y_miss = nr.fit_sample(x, y.ravel())
# Out:
# Before Undersampling, counts of label '1': 183431
# Before Undersampling, counts of label '0': 26162

# %%
print('After Undersampling, the shape of x: {}'.format(x_miss.shape)) 
print('After Undersampling, the shape of y: {} \n'.format(y_miss.shape)) 

print("After Undersampling, counts of label '1': {}".format(sum(y_miss == 1))) 
print("After Undersampling, counts of label '0': {}".format(sum(y_miss == 0)))
# Out:
# After Undersampling, the shape of x: (52324, 34)
# After Undersampling, the shape of y: (52324,)
#
# After Undersampling, counts of label '1': 26162
# After Undersampling, counts of label '0': 26162

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_miss = sc.fit_transform(x_miss)

# %%
#Breaking our input and target variable into train and test data
from sklearn.model_selection import train_test_split
x_miss_train,x_miss_test,y_miss_train,y_miss_test=train_test_split(x_miss,y_miss,test_size=0.2,random_state=42)

# %%
# describing info about train and test set 
print("Number transactions x_train dataset: ", x_miss_train.shape) 
print("Number transactions y_train dataset: ", y_miss_train.shape) 
print("Number transactions x_test dataset: ", x_miss_test.shape) 
print("Number transactions y_test dataset: ", y_miss_test.shape)
# Out:
# Number transactions x_train dataset:  (41859, 34)
# Number transactions y_train dataset:  (41859,)
# Number transactions x_test dataset:  (10465, 34)
# Number transactions y_test dataset:  (10465,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

model = [LogisticRegression(),GaussianNB(),DecisionTreeClassifier()]

for m in model:
    m.fit(x_miss_train,y_miss_train)
    m.score(x_miss_train,y_miss_train)
    pred=m.predict(x_miss_test)
    print('Accuracy score of',m,'is:')
    print(accuracy_score(y_miss_test,pred))
    print(confusion_matrix(y_miss_test,pred))
    print(classification_report(y_miss_test,pred))
    print('==============================================================================================')
    print('\n')
# Out:
# Accuracy score of LogisticRegression() is:
# 0.7805064500716674
# [[3947 1249]
#  [1048 4221]]
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.76      0.77      5196
#          1.0       0.77      0.80      0.79      5269
#
#     accuracy                           0.78     10465
#    macro avg       0.78      0.78      0.78     10465
# weighted avg       0.78      0.78      0.78     10465
#
# ...
#
#
# Accuracy score of GaussianNB() is:
# 0.7266125179168658
# [[4433  763]
#  [2098 3171]]
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.85      0.76      5196
#          1.0       0.81      0.60      0.69      5269
#
#     accuracy                           0.73     10465
#    macro avg       0.74      0.73      0.72     10465
# weighted avg       0.74      0.73      0.72     10465
#
# ...
#
#
# Accuracy score of DecisionTreeClassifier() is:
# 0.7485905398948878
# [[3911 1285]
#  [1346 3923]]
# ...

# %% [markdown]
# LogisticRegression has good metrics.Let's also check ensemble techniques to boostup the accuracy.

# %% [markdown]
# # Using Ensemble Techniques to Boostup our Accuracy

# %%
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier

model = [RandomForestClassifier(),GradientBoostingClassifier()]

for m in model:
    m.fit(x_miss_train,y_miss_train)
    m.score(x_miss_train,y_miss_train)
    pred=m.predict(x_miss_test)
    print('Accuracy score of',m,'is:')
    print(accuracy_score(y_miss_test,pred))
    print(confusion_matrix(y_miss_test,pred))
    print(classification_report(y_miss_test,pred))
    print('==============================================================================================')
    print('\n')
# Out:
# Accuracy score of RandomForestClassifier() is:
# 0.8183468705207836
# [[4106 1090]
#  [ 811 4458]]
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.79      0.81      5196
#          1.0       0.80      0.85      0.82      5269
#
#     accuracy                           0.82     10465
#    macro avg       0.82      0.82      0.82     10465
# weighted avg       0.82      0.82      0.82     10465
#
# ...
#
#
# Accuracy score of GradientBoostingClassifier() is:
# 0.823506927854754
# [[4143 1053]
#  [ 794 4475]]
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.80      0.82      5196
#          1.0       0.81      0.85      0.83      5269
#
#     accuracy                           0.82     10465
#    macro avg       0.82      0.82      0.82     10465
# weighted avg       0.82      0.82      0.82     10465
#
# ...

# %% [markdown]
# GradientBoostingClassifier has good metrics compare with other models. So,we choose GradientBoostingClassifier as the best model.

# %% [markdown]
# ==> From both Oversampling and undersampling,we infer that Oversampling the model gave the better results.
#
# ==> Finally,we chose Random Forest Classifier(which is oversampled) as the best model for predicting the loan defaulter.

# %% [markdown]
# # AUC ROC Curve

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=rf
rfc.fit(x_res_train,y_res_train)
rfc.score(x_res_train,y_res_train)
predrfc=rfc.predict(x_res_test)
print('Accuracy score of',rfc,'is:')
print(accuracy_score(y_res_test,predrfc))
print(confusion_matrix(y_res_test,predrfc))
print(classification_report(y_res_test,predrfc))
# Out:
# Accuracy score of RandomForestClassifier(n_estimators=200) is:
# 0.9508402273315797
# [[34050  2397]
#  [ 1210 35716]]
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.93      0.95     36447
#          1.0       0.94      0.97      0.95     36926
#
#     accuracy                           0.95     73373
#    macro avg       0.95      0.95      0.95     73373
# weighted avg       0.95      0.95      0.95     73373

# %%
rfc=RandomForestClassifier(n_estimators=100,random_state=42)
rfc.fit(x_res_train,y_res_train)
y_pred_prob=rfc.predict_proba(x_res_test)[:,1]
y_pred_prob

fpr,tpr,threshold=roc_curve(y_res_test,y_pred_prob)

plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='RandomForestClassifier()')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc="lower right")
plt.show()
auc_score = roc_auc_score(y_res_test,predrfc)
print(auc_score)
# Out:
# 0.9507325155234687

# %% [markdown]
# Conclusion :
#
# We can conclude the problem by stating that "RandomForestClassifier" is the best model with a good performance metrics and by looking the ROC the model is good. As we know higher the AUC score,better the model. So,the model has good AUC score.
