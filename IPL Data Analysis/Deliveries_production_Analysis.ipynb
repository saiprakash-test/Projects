# %%
# Importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading the dataset
df=pd.read_csv("deliveries.csv")
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
# Checking the columns of the dataset
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
# Checking the shape of the dataset
df.shape
# Out:
# (150460, 21)

# %%
#Checking the unique values in the "batsman" column
df['batsman'].unique()
# Out:
# array(['DA Warner', 'S Dhawan', 'MC Henriques', 'Yuvraj Singh',
#        'DJ Hooda', 'BCJ Cutting', 'CH Gayle', 'Mandeep Singh', 'TM Head',
#        'KM Jadhav', 'SR Watson', 'Sachin Baby', 'STR Binny', 'S Aravind',
#        'YS Chahal', 'TS Mills', 'A Choudhary', 'PA Patel', 'JC Buttler',
#        'RG Sharma', 'N Rana', 'AT Rayudu', 'KH Pandya', 'KA Pollard',
#        'HH Pandya', 'TG Southee', 'AM Rahane', 'MA Agarwal', 'SPD Smith',
#        'BA Stokes', 'MS Dhoni', 'JJ Roy', 'BB McCullum', 'SK Raina',
#        'AJ Finch', 'KD Karthik', 'G Gambhir', 'CA Lynn', 'MK Tiwary',
#        'DT Christian', 'HM Amla', 'M Vohra', 'WP Saha', 'AR Patel',
#        'GJ Maxwell', 'DA Miller', 'Vishnu Vinod', 'Iqbal Abdulla',
#        'P Negi', 'AP Tare', 'SW Billings', 'KK Nair', 'SV Samson',
#        'RR Pant', 'CH Morris', 'CR Brathwaite', 'PJ Cummins', 'A Mishra',
#        'S Nadeem', 'Z Khan', 'DR Smith', 'DS Kulkarni', 'P Kumar',
# ...

# %% [markdown]
# ##### Analysis of Rohit Sharma

# %%
df_rg = df[df['batsman']=='RG Sharma']
df_rg
# Out:
#         match_id  inning    batting_team            bowling_team  over  ball  \
# 275            2       1  Mumbai Indians  Rising Pune Supergiant     5     3
# 276            2       1  Mumbai Indians  Rising Pune Supergiant     5     4
# 278            2       1  Mumbai Indians  Rising Pune Supergiant     5     6
# 279            2       1  Mumbai Indians  Rising Pune Supergiant     6     1
# 285            2       1  Mumbai Indians  Rising Pune Supergiant     7     1
# ...          ...     ...             ...                     ...   ...   ...
# 148781       630       1  Mumbai Indians           Gujarat Lions     3     5
# 148783       630       1  Mumbai Indians           Gujarat Lions     4     1
# 148785       630       1  Mumbai Indians           Gujarat Lions     4     3
# 148786       630       1  Mumbai Indians           Gujarat Lions     4     4
# 148787       630       1  Mumbai Indians           Gujarat Lions     4     5
#
# ...

# %%
plt.figure(figsize = (10,4))
df_rg['dismissal_kind'].value_counts().plot.pie()
plt.legend(bbox_to_anchor=(1.8, 1), loc='upper right');

# %%
def total_count(df_rg,runs):
    return len(df_rg[df_rg['batsman_runs']==runs])*runs

# %% [markdown]
# ## Runs(Singles, Doubles, Fours, Sixes) scored by RG Sharma

# %% [markdown]
# ### Singles

# %%
total_count(df_rg,1)
# Out:
# 1379

# %% [markdown]
# ### Doubles

# %%
total_count(df_rg,2)
# Out:
# 354

# %% [markdown]
# ### Triples

# %%
total_count(df_rg,3)
# Out:
# 15

# %% [markdown]
# ### Fours

# %%
total_count(df_rg,4)
# Out:
# 1416

# %% [markdown]
# ### Sixes

# %%
total_count(df_rg,6)
# Out:
# 1038

# %%
slices=[total_count(df_rg,1),total_count(df_rg,2),total_count(df_rg,3),total_count(df_rg,4),total_count(df_rg,6)]
labels=[1,2,3,4,6]
explode=[0,0,0,0,0.1]
plt.pie(slices,labels=labels,autopct='%1.1f%%',explode=explode)
plt.title("RG Sharma total runs contribution")
plt.tight_layout()
plt.show()

# %%
df['bowling_team'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiant', 'Mumbai Indians',
#        'Kolkata Knight Riders', 'Gujarat Lions', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Deccan Chargers', 'Kochi Tuskers Kerala', 'Pune Warriors',
#        'Rising Pune Supergiants'], dtype=object)

# %%
df['batting_team'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Royal Challengers Bangalore',
#        'Mumbai Indians', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Kolkata Knight Riders', 'Kings XI Punjab', 'Delhi Daredevils',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants'],
#       dtype=object)

# %% [markdown]
# ### Replacing the Team Names with their abbreviations

# %%
Teams={
    'Royal Challengers Bangalore':'RCB', 
    'Sunrisers Hyderabad':'SRH',
       'Rising Pune Supergiant':'RPS',
    'Mumbai Indians':'MI',
       'Kolkata Knight Riders':'KKR', 
    'Gujarat Lions':'GL',
    'Kings XI Punjab':'KXIP',
       'Delhi Daredevils':'DD',
    'Chennai Super Kings':'CSK',
    'Rajasthan Royals':'RR',
       'Deccan Chargers':'DC',
    'Kochi Tuskers Kerala':'KTK',
    'Pune Warriors':'PW',
       'Rising Pune Supergiants':'RPS'
}

# %%
df['batting_team']=df['batting_team'].map(Teams)
df['bowling_team']=df['bowling_team'].map(Teams)

# %% [raw]
# df['batting_team'] = df['batting_team'].replace(['Sunrisers Hyderabad', 'Royal Challengers Bangalore',
#        'Mumbai Indians', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Kolkata Knight Riders', 'Kings XI Punjab', 'Delhi Daredevils',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants'],['SRH','RCB','MI','RPS','GJ','KKR','KXIP','DD','CSK','RR','DC','KTK','PW','RPS'])

# %% [raw]
# df['bowling_team'] = df['bowling_team'].replace(['Sunrisers Hyderabad', 'Royal Challengers Bangalore',
#        'Mumbai Indians', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Kolkata Knight Riders', 'Kings XI Punjab', 'Delhi Daredevils',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants'],['SRH','RCB','MI','RPS','GJ','KKR','KXIP','DD','CSK','RR','DC','KTK','PW','RPS'])

# %%
df.head()
# Out:
#    match_id  inning batting_team bowling_team  over  ball    batsman  \
# 0         1       1          SRH          RCB     1     1  DA Warner
# 1         1       1          SRH          RCB     1     2  DA Warner
# 2         1       1          SRH          RCB     1     3  DA Warner
# 3         1       1          SRH          RCB     1     4  DA Warner
# 4         1       1          SRH          RCB     1     5  DA Warner
#
#   non_striker    bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 0    S Dhawan  TS Mills              0  ...         0            0
# 1    S Dhawan  TS Mills              0  ...         0            0
# 2    S Dhawan  TS Mills              0  ...         0            0
# 3    S Dhawan  TS Mills              0  ...         0            0
# 4    S Dhawan  TS Mills              0  ...         0            0
#
#    noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  \
# 0            0             0             0           0           0
# ...

# %% [markdown]
# #### Score Distribution For Teams by Innings

# %%
runs=df.groupby(['match_id','inning','batting_team'])[['total_runs']].sum().reset_index()
runs
# Out:
#       match_id  inning batting_team  total_runs
# 0            1       1          SRH         207
# 1            1       2          RCB         172
# 2            2       1           MI         184
# 3            2       2          RPS         187
# 4            3       1           GL         183
# ...        ...     ...          ...         ...
# 1279       634       2          KKR         140
# 1280       635       1           GL         162
# 1281       635       2          SRH         163
# 1282       636       1          SRH         208
# 1283       636       2          RCB         200
#
# [1284 rows x 4 columns]

# %%
runs.drop('match_id',axis=1,inplace=True)
runs
# Out:
#       inning batting_team  total_runs
# 0          1          SRH         207
# 1          2          RCB         172
# 2          1           MI         184
# 3          2          RPS         187
# 4          1           GL         183
# ...      ...          ...         ...
# 1279       2          KKR         140
# 1280       1           GL         162
# 1281       2          SRH         163
# 1282       1          SRH         208
# 1283       2          RCB         200
#
# [1284 rows x 3 columns]

# %%
runs=df.groupby(['match_id','inning','batting_team'])[['total_runs']].sum().reset_index()
runs.drop('match_id',axis=1,inplace=True)

# %%
inning1=runs[runs['inning']==1]
inning2=runs[runs['inning']==2]

# %%
sns.boxplot(x='batting_team',y='total_runs',data=inning1)
# Out:
# <AxesSubplot:xlabel='batting_team', ylabel='total_runs'>

# %% [markdown]
# ##### According to this plot, the batting by CSK & RCB is best.

# %%
sns.boxplot(x='batting_team',y='total_runs',data=inning2)
# Out:
# <AxesSubplot:xlabel='batting_team', ylabel='total_runs'>

# %% [markdown]
# ##### This plot is also same as above.

# %% [markdown]
# ##### How many times teams scores more than 200

# %%
high_scores=df.groupby(['match_id', 'inning','batting_team','bowling_team'])['total_runs'].sum().reset_index() 
high_scores
# Out:
#       match_id  inning batting_team bowling_team  total_runs
# 0            1       1          SRH          RCB         207
# 1            1       2          RCB          SRH         172
# 2            2       1           MI          RPS         184
# 3            2       2          RPS           MI         187
# 4            3       1           GL          KKR         183
# ...        ...     ...          ...          ...         ...
# 1279       634       2          KKR          SRH         140
# 1280       635       1           GL          SRH         162
# 1281       635       2          SRH           GL         163
# 1282       636       1          SRH          RCB         208
# 1283       636       2          RCB          SRH         200
#
# [1284 rows x 5 columns]

# %%
score_200=high_scores[high_scores['total_runs']>=200]
score_200
# Out:
#       match_id  inning batting_team bowling_team  total_runs
# 0            1       1          SRH          RCB         207
# 16           9       1           DD          RPS         205
# 38          20       1          RCB           GL         213
# 62          32       1          SRH         KXIP         207
# 72          36       1          SRH          KKR         209
# ...        ...     ...          ...          ...         ...
# 1250       620       1          RCB           GL         248
# 1256       623       1           MI           DD         206
# 1262       626       1          RCB         KXIP         211
# 1282       636       1          SRH          RCB         208
# 1283       636       2          RCB          SRH         200
#
# [67 rows x 5 columns]

# %%
plt.figure(figsize=(12,8))
sns.countplot(score_200['batting_team']);

# %% [markdown]
# ###### RCB scored above 200 most

# %%
plt.figure(figsize=(12,8))
sns.countplot(score_200['bowling_team']);

# %% [markdown]
# ##### The bowling team with more number of times scored above 200 runs is KXIP .

# %% [markdown]
# ##### how many times team scores >200 runs against batting team

# %%
high_200=df.groupby(['match_id', 'inning','batting_team','bowling_team'])['total_runs'].sum().reset_index()
high_200.set_index(['match_id'],inplace=True)

# %%
high_200['total_runs'].max()
# Out:
# 263

# %%
high_200.columns
# Out:
# Index(['inning', 'batting_team', 'bowling_team', 'total_runs'], dtype='object')

# %%
high_200.head()
# Out:
#           inning batting_team bowling_team  total_runs
# match_id
# 1              1          SRH          RCB         207
# 1              2          RCB          SRH         172
# 2              1           MI          RPS         184
# 2              2          RPS           MI         187
# 3              1           GL          KKR         183

# %%
high=high_200.rename(columns={'total_runs':'count'})
high=high[high['count']>=200].groupby(['inning','batting_team','bowling_team']).count()
high
# Out:
#                                   count
# inning batting_team bowling_team
# 1      CSK          DD                1
#                     KKR               1
#                     KXIP              2
#                     MI                1
#                     RCB               1
#                     RR                1
#                     SRH               2
#        DC           RR                1
#        DD           KXIP              1
#                     MI                1
#                     RPS               1
#        GL           DD                1
#        KKR          DC                1
#                     KXIP              1
#                     RCB               1
#        KXIP         CSK               2
#                     MI                1
#                     RCB               2
#                     RR                1
#        MI           CSK               1
#                     DD                4
# ...

# %% [markdown]
# ##### Batsman Comparison

# %%
balls=df.groupby(['batsman'])['ball'].count().reset_index()
balls
# Out:
#             batsman  ball
# 0    A Ashish Reddy   196
# 1        A Chandila     7
# 2          A Chopra    75
# 3       A Choudhary    20
# 4        A Flintoff    57
# ..              ...   ...
# 456     YV Takawale   183
# 457   Yashpal Singh    67
# 458     Younis Khan     7
# 459    Yuvraj Singh  2050
# 460          Z Khan   141
#
# [461 rows x 2 columns]

# %%
runs=df.groupby(['batsman'])['batsman_runs'].sum().reset_index()
runs.columns=['batsman','runs']
runs
# Out:
#             batsman  runs
# 0    A Ashish Reddy   280
# 1        A Chandila     4
# 2          A Chopra    53
# 3       A Choudhary    25
# 4        A Flintoff    62
# ..              ...   ...
# 456     YV Takawale   192
# 457   Yashpal Singh    47
# 458     Younis Khan     3
# 459    Yuvraj Singh  2591
# 460          Z Khan   117
#
# [461 rows x 2 columns]

# %%
df.groupby(['batsman'])['batsman_runs'].agg(sum)
# Out:
# batsman
# A Ashish Reddy     280
# A Chandila           4
# A Chopra            53
# A Choudhary         25
# A Flintoff          62
#                   ...
# YV Takawale        192
# Yashpal Singh       47
# Younis Khan          3
# Yuvraj Singh      2591
# Z Khan             117
# Name: batsman_runs, Length: 461, dtype: int64

# %%
balls=balls.merge(runs,left_on='batsman',right_on='batsman',how='outer')

# %%
four=df[df['batsman_runs']==4]

# %%
''' df.groupby('batsman')['batsman_runs'].agg(lambda x: (x==4).sum()).reset_index()'''

runs_4=four.groupby('batsman')['batsman_runs'].count().reset_index()
runs_4.columns=['batsman','4s']
runs_4
# Out:
#             batsman   4s
# 0    A Ashish Reddy   16
# 1          A Chopra    7
# 2       A Choudhary    1
# 3        A Flintoff    5
# 4          A Kumble    3
# ..              ...  ...
# 363       YK Pathan  240
# 364     YV Takawale   26
# 365   Yashpal Singh    5
# 366    Yuvraj Singh  205
# 367          Z Khan   11
#
# [368 rows x 2 columns]

# %%
six=df.groupby('batsman')['batsman_runs'].agg(lambda x: (x==6).sum()).reset_index()
six.columns=['batsman','6s']
six
# Out:
#             batsman   6s
# 0    A Ashish Reddy   15
# 1        A Chandila    0
# 2          A Chopra    0
# 3       A Choudhary    1
# 4        A Flintoff    2
# ..              ...  ...
# 456     YV Takawale    3
# 457   Yashpal Singh    0
# 458     Younis Khan    0
# 459    Yuvraj Singh  141
# 460          Z Khan    2
#
# [461 rows x 2 columns]

# %%
player=pd.concat([runs,balls.iloc[:,1],runs_4.iloc[:,1],six.iloc[:,1]],axis=1)
player
# Out:
#             batsman  runs  ball    4s   6s
# 0    A Ashish Reddy   280   196  16.0   15
# 1        A Chandila     4     7   7.0    0
# 2          A Chopra    53    75   1.0    0
# 3       A Choudhary    25    20   5.0    1
# 4        A Flintoff    62    57   3.0    2
# ..              ...   ...   ...   ...  ...
# 456     YV Takawale   192   183   NaN    3
# 457   Yashpal Singh    47    67   NaN    0
# 458     Younis Khan     3     7   NaN    0
# 459    Yuvraj Singh  2591  2050   NaN  141
# 460          Z Khan   117   141   NaN    2
#
# [461 rows x 5 columns]

# %%
player['strike_rate']=player['runs']/player['ball']
player.head()
# Out:
#           batsman  runs  ball    4s  6s  strike_rate
# 0  A Ashish Reddy   280   196  16.0  15     1.428571
# 1      A Chandila     4     7   7.0   0     0.571429
# 2        A Chopra    53    75   1.0   0     0.706667
# 3     A Choudhary    25    20   5.0   1     1.250000
# 4      A Flintoff    62    57   3.0   2     1.087719

# %%
player.isna().sum()
# Out:
# batsman         0
# runs            0
# ball            0
# 4s             93
# 6s              0
# strike_rate     0
# dtype: int64

# %%
player['4s'].fillna(0,inplace=True)

# %%
player.isnull().values.any()
# Out:
# False

# %%
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
grp=df.groupby(['match_id','batsman','batting_team'])['batsman_runs'].sum().reset_index()
grp
# Out:
#       match_id       batsman batting_team  batsman_runs
# 0            1   A Choudhary          RCB             6
# 1            1   BCJ Cutting          SRH            16
# 2            1      CH Gayle          RCB            32
# 3            1     DA Warner          SRH            14
# 4            1      DJ Hooda          SRH            16
# ...        ...           ...          ...           ...
# 9510       636     SR Watson          RCB            11
# 9511       636     STR Binny          RCB             9
# 9512       636   Sachin Baby          RCB            18
# 9513       636       V Kohli          RCB            54
# 9514       636  Yuvraj Singh          SRH            38
#
# [9515 rows x 4 columns]

# %%
max=grp.groupby(['batsman'])['batsman_runs'].max().reset_index()
max.columns=['batsman','max_runs']
max
# Out:
#             batsman  max_runs
# 0    A Ashish Reddy        36
# 1        A Chandila         4
# 2          A Chopra        24
# 3       A Choudhary        15
# 4        A Flintoff        24
# ..              ...       ...
# 456     YV Takawale        45
# 457   Yashpal Singh        20
# 458     Younis Khan         3
# 459    Yuvraj Singh        83
# 460          Z Khan        23
#
# [461 rows x 2 columns]

# %%
player2=pd.concat([player,max.iloc[:,1:3]],axis=1)
player2
# Out:
#             batsman  runs  ball    4s   6s  strike_rate  max_runs
# 0    A Ashish Reddy   280   196  16.0   15     1.428571        36
# 1        A Chandila     4     7   7.0    0     0.571429         4
# 2          A Chopra    53    75   1.0    0     0.706667        24
# 3       A Choudhary    25    20   5.0    1     1.250000        15
# 4        A Flintoff    62    57   3.0    2     1.087719        24
# ..              ...   ...   ...   ...  ...          ...       ...
# 456     YV Takawale   192   183   0.0    3     1.049180        45
# 457   Yashpal Singh    47    67   0.0    0     0.701493        20
# 458     Younis Khan     3     7   0.0    0     0.428571         3
# 459    Yuvraj Singh  2591  2050   0.0  141     1.263902        83
# 460          Z Khan   117   141   0.0    2     0.829787        23
#
# [461 rows x 7 columns]

# %%
player2.shape
# Out:
# (461, 7)

# %% [markdown]
# #### Top 10 Batsman

# %%
max_runs=df.groupby(['batsman'])['batsman_runs'].sum()
max_runs.sort_values(ascending=False)[:10].plot.bar();

# %% [markdown]
# #### SK Raina has highest total runs across all seasons Whereas Virat Kohliis just few runs behind with the second spot

# %% [markdown]
# ## Top Individual Scores

# %%
df.groupby(["match_id","batsman",'batting_team'])["batsman_runs"].sum().reset_index().sort_values(by='batsman_runs', ascending=False).head(10)
# Out:
#       match_id         batsman batting_team  batsman_runs
# 6200       411        CH Gayle          RCB           175
# 900         60     BB McCullum          KKR           158
# 8426       562  AB de Villiers          RCB           133
# 9257       620  AB de Villiers          RCB           129
# 5585       372        CH Gayle          RCB           128
# 3135       206         M Vijay          CSK           127
# 529         36       DA Warner          SRH           126
# 7752       516        V Sehwag         KXIP           122
# 3686       243     PC Valthaty         KXIP           120
# 4223       279        V Sehwag           DD           119

# %% [markdown]
# ### Not only Gayle but there are many RCB players on the top scores list. Looks like RCB is a very formidable batting side.

# %% [markdown]
# ##### Highest Wicket Taker

# %%
df['dismissal_kind'].unique()
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'caught and bowled',
#        'stumped', 'retired hurt', 'hit wicket', 'obstructing the field'],
#       dtype=object)

# %%
dismissal_kinds = ['caught', 'bowled', 'lbw', 'caught and bowled',
       'stumped', 'hit wicket']

# %%
hwt=df[df["dismissal_kind"].isin(dismissal_kinds)]
hwt.head()
# Out:
#      match_id  inning batting_team bowling_team  over  ball        batsman  \
# 11          1       1          SRH          RCB     2     5      DA Warner
# 64          1       1          SRH          RCB    11     3       S Dhawan
# 94          1       1          SRH          RCB    16     2   MC Henriques
# 116         1       1          SRH          RCB    19     4   Yuvraj Singh
# 160         1       2          RCB          SRH     6     4  Mandeep Singh
#
#       non_striker       bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 11       S Dhawan  A Choudhary              0  ...         0            0
# 64   MC Henriques    STR Binny              0  ...         0            0
# 94   Yuvraj Singh    YS Chahal              0  ...         0            0
# 116      DJ Hooda     TS Mills              0  ...         0            0
# 160      CH Gayle  Rashid Khan              0  ...         0            0
#
# ...

# %%
hwt['bowler'].value_counts()[:10].plot.bar();

# %% [markdown]
# ##### SL Malinga took most wickets
